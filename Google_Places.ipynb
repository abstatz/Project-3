# %%
#Dependencies
import requests
import json
import pandas as pd

#Google developer API Key
from config import gkey

# %%
# Geo coordinates
target_coordinates = "30.266666, -97.733330"
target_search = "Bars"
target_radius = 8000
target_type = "bars"

# set up parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response = requests.get(base_url, params=params)

# %%
# print the response url
# print(response.url)

# %%
# convert response to json
places_data = response.json()

# Print pretty
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "ATtYBwIzTqRD3GOMBTPwH1KrjX9mQAbqSYfMdq2dJ4adtegRwvGMAb-LVQNpNKolVph1KAUnMDz66s-7J0S460BjbGOFXlYFBLBY56S2rCOERrIGsX0Cvy3VXMeQaX6PExHuTV5iJdM8x0n_EKMPBx1si95a8Xk0AdU4fRHNzu1GEDWEDXL33I16nQ9rqgHLtZajCYiDkzyFdANHwRgSTS1r3sQTUbIBn8tSW7_YmTrGAqjSzb87lftsTxkbHnfjAhmM4HIYPZXRGqaQkyct2DHuzThIYDKZD4b9btOgOs4xzdUdkoI0R00lmRDEyUOQ-FsBPeXvousBKHgBbT4SdORR-e4dKRgR21Z-FmhIktjEqRgvAWHYW8oeW2-D288bKphZKERnzlEOdkxmVMIUclGPe91N7UG83PZWauyi0O_rnjiI3N7OG-B5RlsI5Cvo",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.249437,
#                     "lng": -97.766893
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.25090932989272,
#                         "lng": -97.76570852010728
#                     },
#                     "southwest": {
#                         "lat": 30.24820967010728,
#                         "lng": -97.76840817989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png",
#             "name": "Corner Bar",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3648,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100335561761196663504\">Corner Bar</a>"
#                     ],
#                     "photo_reference": "ATtYBwIzSVE6PCO8M1IXPeM87klkuDTAkQN042RKxCIX2VBYnuuhSLtQj-LGB9G-Sq9lya0oghpUq2PyNjMyxjuV3JlmOCG7a_y_tTn5bXJrUgyzoKIB7H7vexCnkKrWMUsbZaQ8wVZNTE56v_LInlLatahrmeTvCpu3Of-0VzcjQyjhyM8N",
#                     "width": 5472
#                 }
#             ],
#             "place_id": "ChIJc8VGEN-0RIYR_47qj-CsoQw",
#             "plus_code": {
#                 "compound_code": "66XM+Q6 Austin, Texas",
#                 "global_code": "862466XM+Q6"
#             },
#             "price_level": 1,
#             "rating": 4.5,
#             "reference": "ChIJc8VGEN-0RIYR_47qj-CsoQw",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 363,
#             "vicinity": "1901 S Lamar Blvd, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.2637681,
#                     "lng": -97.7277878
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.26499182989273,
#                         "lng": -97.72649692010728
#                     },
#                     "southwest": {
#                         "lat": 30.26229217010728,
#                         "lng": -97.72919657989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "Revelry Kitchen + Bar",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105213997872664021360\">Matt Templon</a>"
#                     ],
#                     "photo_reference": "ATtYBwIuf4HNnYQ7ihKqr9TvPDin2uVe2uM1J8OMIaPkHTwbX41cNvq1yFYT0tbASwRgWtTdnVizFHYaOWT5MwkGYHt9KxoBViOyaxRwnu7l0Vr6s5MwNeEcy72TEk_4DXu8rIRuCpby5UQhEyZjexh8gIP7EZr5iH5DJY8Ko1o_N54nBjO1",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJUyhv87C1RIYRWred_z5PwqE",
#             "plus_code": {
#                 "compound_code": "777C+GV Austin, Texas",
#                 "global_code": "8624777C+GV"
#             },
#             "price_level": 2,
#             "rating": 4.4,
#             "reference": "ChIJUyhv87C1RIYRWred_z5PwqE",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 464,
#             "vicinity": "1410 E 6th St, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.317858,
#                     "lng": -97.72203599999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.31910702989272,
#                         "lng": -97.72069857010726
#                     },
#                     "southwest": {
#                         "lat": 30.31640737010727,
#                         "lng": -97.72339822989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png",
#             "name": "Workhorse Bar",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2160,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104646941759218543815\">Alan Cumming</a>"
#                     ],
#                     "photo_reference": "ATtYBwLozYUTsT9qchUry7ViGS4b-ZpncCBL_8IVWVc-ZQFbkpOXaIHmYUUi0U6-_bOQg2D8T2efPbHy3cSAMmPL-WFRfGFHwRHjzYXBtQqKxqQfS3lpp7i3aG-AAI_P8l8a24WdX9dDzqJfTf9G1InlW08X1wbJB-ztVLKOZKmbJ1zBvjDa",
#                     "width": 2880
#                 }
#             ],
#             "place_id": "ChIJg4G4emvKRIYRbQfi7duy1zI",
#             "plus_code": {
#                 "compound_code": "879H+45 Austin, Texas",
#                 "global_code": "8624879H+45"
#             },
#             "price_level": 1,
#             "rating": 4.6,
#             "reference": "ChIJg4G4emvKRIYRbQfi7duy1zI",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 598,
#             "vicinity": "100 N Loop Blvd E #B, Austin"
#         },
#         {
#             "business_status": "CLOSED_TEMPORARILY",
#             "geometry": {
#                 "location": {
#                     "lat": 30.279892,
#                     "lng": -97.742087
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.28110477989273,
#                         "lng": -97.74065227010726
#                     },
#                     "southwest": {
#                         "lat": 30.27840512010728,
#                         "lng": -97.74335192989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png",
#             "name": "Dive Bar & Lounge",
#             "permanently_closed": true,
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115062202810707933965\">caraleones54</a>"
#                     ],
#                     "photo_reference": "ATtYBwIphpe18EhOo0y6dULsGgVxe9CjJK8LFPPcsl3J-qX3qkJPv1iOBVqmvjJD4rBxGF-4YLEZUjmUPy4TXdqBMqMopMDcM-JYN6dPED3b0HvG-Vxog3Qsbt7X7panwvIYlmnMJdNBQT6e3VkMgkaI3V8vhKmkKjZmL8issyv5oj2mnpc",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJI8PZjXW1RIYRjmyX7kkdbas",
#             "plus_code": {
#                 "compound_code": "77H5+X5 Austin, Texas",
#                 "global_code": "862477H5+X5"
#             },
#             "price_level": 2,
#             "rating": 4.4,
#             "reference": "ChIJI8PZjXW1RIYRjmyX7kkdbas",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 265,
#             "vicinity": "1703 Guadalupe St, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.2412675,
#                     "lng": -97.785023
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.24259047989272,
#                         "lng": -97.78371372010729
#                     },
#                     "southwest": {
#                         "lat": 30.23989082010728,
#                         "lng": -97.78641337989274
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png",
#             "name": "Lavaca St Bar",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1960,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116179019041961884054\">Jonas Clark</a>"
#                     ],
#                     "photo_reference": "ATtYBwLKhGfqZ8YV6eLWm9aR0ryxM1ZHSP7vVqqmPdeJgT9IQvuvxjNnG_goCUfKLwJ7Z3Zb6LeiuLUVFg-Pr92TAoH0H8p8DDm2Kt1n0hxrEXlQFgOEez8qYQ_jXL9Xl1zCtgriwN6i7vzG8QLzedrEWC9Arb1TN1H4XR3sqZf0nsBZrn5b",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJ6X91GNO0RIYRwfHTBEitpow",
#             "plus_code": {
#                 "compound_code": "66R7+GX Austin, Texas",
#                 "global_code": "862466R7+GX"
#             },
#             "price_level": 2,
#             "rating": 4.4,
#             "reference": "ChIJ6X91GNO0RIYRwfHTBEitpow",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 263,
#             "vicinity": "3121 S Lamar Blvd, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.269952,
#                     "lng": -97.748538
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.27122912989273,
#                         "lng": -97.74711097010729
#                     },
#                     "southwest": {
#                         "lat": 30.26852947010728,
#                         "lng": -97.74981062989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png",
#             "name": "Star Bar",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 854,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115955794622064747459\">Star Bar</a>"
#                     ],
#                     "photo_reference": "ATtYBwKF0ImLow_eCIuwlC0FqZNbGfGn37kr2yYteuy0A9t9nxProPh_yggQGHNocemrnuhtgKRglqUul6XIlQUjcxR_C507V02iF7MqvjEpgBSvBGKHQMnIk7cuUiglz367HrsOoPoAdsu1TiuHnh7soAJluvfvm4rsi2x5mT0_wPahCApc",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJQX0zIAy1RIYRETIq4N928nI",
#             "plus_code": {
#                 "compound_code": "7792+XH Austin, Texas",
#                 "global_code": "86247792+XH"
#             },
#             "price_level": 2,
#             "rating": 4.1,
#             "reference": "ChIJQX0zIAy1RIYRETIq4N928nI",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 376,
#             "vicinity": "600 W 6th St, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.2848235,
#                     "lng": -97.71758559999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.28612307989272,
#                         "lng": -97.71634147010728
#                     },
#                     "southwest": {
#                         "lat": 30.28342342010728,
#                         "lng": -97.71904112989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "Haymaker",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100320048042081127629\">Alan Pasquali</a>"
#                     ],
#                     "photo_reference": "ATtYBwI2A2OsEz3_h_DTQtDMhalVBnTciH8eGdBQvGNtUKOsTvl6t_SrVQfSZD08FVPRO33gEoFhcoS09O8fNV8S83RwsXzSkJ4T3RYLBIG69Dy_8xCWnFim6zUWaIv0N6CG6ndnRH8IdRLcMPE2R2WbxNgyo6N7d47LkCR7R83RVRHdS_3D",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJf0ia8-y1RIYR-xO1mwc4hpo",
#             "plus_code": {
#                 "compound_code": "77MJ+WX Austin, Texas",
#                 "global_code": "862477MJ+WX"
#             },
#             "price_level": 2,
#             "rating": 4.3,
#             "reference": "ChIJf0ia8-y1RIYR-xO1mwc4hpo",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1576,
#             "vicinity": "2310 Manor Rd, Austin"
#         },
#         {
#             "business_status": "CLOSED_TEMPORARILY",
#             "geometry": {
#                 "location": {
#                     "lat": 30.2677886,
#                     "lng": -97.74627729999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.26924007989273,
#                         "lng": -97.74488637010727
#                     },
#                     "southwest": {
#                         "lat": 30.26654042010728,
#                         "lng": -97.7475860298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png",
#             "name": "The Roosevelt Room",
#             "permanently_closed": true,
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101112606999565933057\">Samuel Reisler</a>"
#                     ],
#                     "photo_reference": "ATtYBwLd5ZTH5ZmfBhIUn3-3v-VcxhUw5E_7_qevjIHo8M62W0dRhNCs3Db2NTELbRRSwndn9gxI82-7205MWr65Otiwa1yItPzLdCBQ2S4IN8M5PzDTpA_WCtDlCMC6vt7T1-rXVxPb2BNa4lSwLg0_WcaEVUgJa7j65fNFlSVqBRsIChVG",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJIeohJQm1RIYRG-NyRBlsnuw",
#             "plus_code": {
#                 "compound_code": "7793+4F Austin, Texas",
#                 "global_code": "86247793+4F"
#             },
#             "price_level": 3,
#             "rating": 4.7,
#             "reference": "ChIJIeohJQm1RIYRG-NyRBlsnuw",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1229,
#             "vicinity": "307 W 5th St, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.2550175,
#                     "lng": -97.7619162
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.25637592989272,
#                         "lng": -97.76054967010728
#                     },
#                     "southwest": {
#                         "lat": 30.25367627010727,
#                         "lng": -97.76324932989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png",
#             "name": "Gibson Street Bar",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2268,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100451961417008967325\">John Kelly</a>"
#                     ],
#                     "photo_reference": "ATtYBwIfnsaKJ3Ske7C8YX5u0X24QaEoDVBCQX_zDEMJlxphpQfKpsTjhATOkHXSTrrl17SRg1qhnggLElYlFq0DAj4lqtcScjwRQN_rnsRzMi6Ms0Tc-fDLA4xySQ1Kfmxao_QzazhNLPnUVVGMQH3l3t3nEukVnuzn2myo0xxti0mslbNh",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJG_AQDB-1RIYRuUqbwL-S63Y",
#             "plus_code": {
#                 "compound_code": "764Q+26 Austin, Texas",
#                 "global_code": "8624764Q+26"
#             },
#             "price_level": 2,
#             "rating": 4.3,
#             "reference": "ChIJG_AQDB-1RIYRuUqbwL-S63Y",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 571,
#             "vicinity": "1109 S Lamar Blvd, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.2645703,
#                     "lng": -97.7438317
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.26595612989272,
#                         "lng": -97.74260487010727
#                     },
#                     "southwest": {
#                         "lat": 30.26325647010727,
#                         "lng": -97.74530452989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "Corner Restaurant & Bar",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114960696292353789576\">Yael</a>"
#                     ],
#                     "photo_reference": "ATtYBwKaReOclwvl-TGinYkyDwbAXh__uj6Y7VWoFHRvICER12JYdSUg3XohI1QvZlR_P4H5F9sIBGOYX_tXfveJNRcwCu2eaNjNtWq-YgD_pY_aU-EukNKEv08t3TdeSBBlWXbXo0cAyPbsNw5_y5tUJec-gfm9P2I6NGC5yxX9WCV6ZWU-",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJxcCceAi1RIYR9AqXT8eWDyc",
#             "plus_code": {
#                 "compound_code": "7774+RF Austin, Texas",
#                 "global_code": "86247774+RF"
#             },
#             "price_level": 2,
#             "rating": 4.5,
#             "reference": "ChIJxcCceAi1RIYR9AqXT8eWDyc",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "bar",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1056,
#             "vicinity": "110 E 2nd St, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.2877778,
#                     "lng": -97.74444439999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.28914237989272,
#                         "lng": -97.74320892010728
#                     },
#                     "southwest": {
#                         "lat": 30.28644272010727,
#                         "lng": -97.74590857989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png",
#             "name": "Cain & Abel's",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 725,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101441843762275972730\">Cain &amp; Abel&#39;s</a>"
#                     ],
#                     "photo_reference": "ATtYBwIRNIWrNgQZn1Pwq-aq0QbWD3xJL_Q3P9-5noskSbqeUZvIfsaxE1JQbWqLjjMzr7JLUTnehaSOF_7HiQPK_U7ATgstL-aya0iKBlAdSGouMJDhZJew7w9esWxxHzGDQCo17FLN-H9bfcCPH9l6sL1H1zqRtb9DYquHP07G-eAePep9",
#                     "width": 1200
#                 }
#             ],
#             "place_id": "ChIJe5Fr03m1RIYRBeohh0J9LOQ",
#             "plus_code": {
#                 "compound_code": "77Q4+46 Austin, Texas",
#                 "global_code": "862477Q4+46"
#             },
#             "price_level": 1,
#             "rating": 4,
#             "reference": "ChIJe5Fr03m1RIYRBeohh0J9LOQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 340,
#             "vicinity": "2313 Rio Grande St, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.2219997,
#                     "lng": -97.68851459999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.22340072989272,
#                         "lng": -97.68699017010726
#                     },
#                     "southwest": {
#                         "lat": 30.22070107010727,
#                         "lng": -97.68968982989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "The Garden Grille & Bar",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 390,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114390849356125744159\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwLAChHhuO5D3oerLozgk6hPkD0F9l5EQ_mTka88meSrtnDA-Scbt7Bls_ZwFLEhsw83JQlIPsFtFnoo97rSQdnH4If9OVjTGSL-eipq9AW5UxyKqS5GGqAkr968nKzCr4BpVaV30s9iHLpgtnfcOBsDXxHF7wddC4rBEAtkc8KPta37",
#                     "width": 698
#                 }
#             ],
#             "place_id": "ChIJJazCjK-2RIYR8HsVsgkKvn4",
#             "plus_code": {
#                 "compound_code": "68C6+QH Austin, Texas",
#                 "global_code": "862468C6+QH"
#             },
#             "rating": 4.2,
#             "reference": "ChIJJazCjK-2RIYR8HsVsgkKvn4",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 53,
#             "vicinity": "7610 John Glenn Way, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.2666203,
#                     "lng": -97.74205359999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.26806112989272,
#                         "lng": -97.74068112010727
#                     },
#                     "southwest": {
#                         "lat": 30.26536147010728,
#                         "lng": -97.74338077989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png",
#             "name": "HandleBar",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115805671985961381853\">Emily Thomas</a>"
#                     ],
#                     "photo_reference": "ATtYBwKd0-Hx5BtU_LJqhthVAzDIbLdGy_GTiXrLj5qlgfq-pLezASi9y6L8NgcbhRZgB_bd2JxiqKs0GaqyGDCjdPH_f6_OFkdw9OM1VMMA3shLVyeJIIlXvTyNecG3HVbHaH7sYpR7TCosGuUbKTXPWylOM18o6aGs48REjJ6EjkmQ01Hb",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJixveLgi1RIYRg-FziMQPbwk",
#             "plus_code": {
#                 "compound_code": "7785+J5 Austin, Texas",
#                 "global_code": "86247785+J5"
#             },
#             "price_level": 1,
#             "rating": 4.4,
#             "reference": "ChIJixveLgi1RIYRg-FziMQPbwk",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "night_club",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1235,
#             "vicinity": "121 E 5th St, Austin"
#         },
#         {
#             "business_status": "CLOSED_TEMPORARILY",
#             "geometry": {
#                 "location": {
#                     "lat": 30.2655193,
#                     "lng": -97.7402735
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.26692182989273,
#                         "lng": -97.73906597010729
#                     },
#                     "southwest": {
#                         "lat": 30.26422217010728,
#                         "lng": -97.74176562989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "Champions Sports Bar",
#             "permanently_closed": true,
#             "photos": [
#                 {
#                     "height": 423,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112831401961718862635\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwKEwFMQXUzssAFYvUpXU69KyDkjUaxyVCF0XX1Z6TtLEFHydXZF2oo6DI-GLuVHVkotsn5f2HWUimlSlgkMXUmc0TCs5pkUTz9BOdMH_qB2JL1zx1lyOrgwOgoh1VeukjQR0Ft1h5PnhFxPHNNJuSkRVkH87F8HyZW_WT5HItNc2hil",
#                     "width": 610
#                 }
#             ],
#             "place_id": "ChIJz0VP7Ke1RIYRMCTWwLcB35Q",
#             "plus_code": {
#                 "compound_code": "7785+6V Austin, Texas",
#                 "global_code": "86247785+6V"
#             },
#             "price_level": 2,
#             "rating": 3.6,
#             "reference": "ChIJz0VP7Ke1RIYRMCTWwLcB35Q",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 284,
#             "vicinity": "300 E 4th St, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.2697219,
#                     "lng": -97.7493899
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.27114617989273,
#                         "lng": -97.74797682010727
#                     },
#                     "southwest": {
#                         "lat": 30.26844652010729,
#                         "lng": -97.75067647989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png",
#             "name": "Key Bar",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101454566003418349426\">Key Bar</a>"
#                     ],
#                     "photo_reference": "ATtYBwJYfmBu4TmhP7qJ9wY03nZOZzFKL9hAphR4nF1YYMixPGIUfhogGTcbW4YByQDFp7WIPEtN9PLTyLLaH3wzPoXoWMw8x3jqRuWmpPtmx-hZR98qrOaUZzJ4GKtXGlwa_KeCAIXr21DFqBgsU6l7IU4RZjyCSrJGrFYT12zd6sXwS9el",
#                     "width": 1500
#                 }
#             ],
#             "place_id": "ChIJZ4ToKQy1RIYRfYEr57bNgOM",
#             "plus_code": {
#                 "compound_code": "7792+V6 Austin, Texas",
#                 "global_code": "86247792+V6"
#             },
#             "price_level": 1,
#             "rating": 4.3,
#             "reference": "ChIJZ4ToKQy1RIYRfYEr57bNgOM",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "night_club",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 307,
#             "vicinity": "617 W 6th St, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.268651,
#                     "lng": -97.728072
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.27004692989273,
#                         "lng": -97.72671037010727
#                     },
#                     "southwest": {
#                         "lat": 30.26734727010728,
#                         "lng": -97.72941002989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png",
#             "name": "Nickel City",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113414841699244358288\">Sean Langan</a>"
#                     ],
#                     "photo_reference": "ATtYBwL1w3C2p-q0XxbowpbWJu2IwKvR9S9qH7aZuS4NtEbznOC1_PyJW-ILBBBFNXbMv99BkC2btcPouEb5Y4pQ0eJPZJR1pMV3W1w6MHnz0ImDqG0Ev_rufk3vTeX-W0OVB0Zb0ITyB6xwJAHM_ukQNlfvz5obBmYtfOZXRcB2u7ckcnZb",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJETpRB7u1RIYRDwQmAJdd-Wc",
#             "plus_code": {
#                 "compound_code": "779C+FQ Austin, Texas",
#                 "global_code": "8624779C+FQ"
#             },
#             "price_level": 1,
#             "rating": 4.6,
#             "reference": "ChIJETpRB7u1RIYRDwQmAJdd-Wc",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 595,
#             "vicinity": "1133 E 11th St, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.2640927,
#                     "lng": -97.7425827
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.26543607989272,
#                         "lng": -97.74134747010727
#                     },
#                     "southwest": {
#                         "lat": 30.26273642010728,
#                         "lng": -97.74404712989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "Cedar Door Patio Bar & Grill",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114459752477528684640\">turtlesoup</a>"
#                     ],
#                     "photo_reference": "ATtYBwJBqYuvtCKW9MJ83R4mkblqoCnPpsPSrbWXG_sa8BP2LTgtb2PerCnddHiMn3A5KTrOt00IJn76LXN2QFG3dKplPQ10motzbH6dMDL-uWOFsqQEYgagCL2kfJOrnn-PDUMTeJkRHJJ6t6A5NtJXABkzPRF7cYbOJmgoPtOaKP6Iem0V",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJwd-t5ge1RIYRfg8ZQBcWbYE",
#             "plus_code": {
#                 "compound_code": "7774+JX Austin, Texas",
#                 "global_code": "86247774+JX"
#             },
#             "price_level": 2,
#             "rating": 4.3,
#             "reference": "ChIJwd-t5ge1RIYRfg8ZQBcWbYE",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1039,
#             "vicinity": "201 Brazos St bldg A, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.2729938,
#                     "lng": -97.7571715
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.27424902989272,
#                         "lng": -97.75590997010728
#                     },
#                     "southwest": {
#                         "lat": 30.27154937010728,
#                         "lng": -97.75860962989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "Clark's Oyster Bar",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110900278354930955620\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwI6tzk4GhPhvkVGwdjlfkBCZVcr0hMlEN00oJrxZ7-KemtDrXDSWd54R98Xe2O9z8PM1xGG-TjlajAC_ooZ1io4diHY7ze4_U31u-ngwSKx1SXXzamD9YPX7BSey1ddFhwmax8NuzPeOJFOTwcgQGsicXdanHQuALiAZPSIj7tQPgEJ",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJbeqvYxO1RIYR5zZEcyfr02s",
#             "plus_code": {
#                 "compound_code": "76FV+54 Austin, Texas",
#                 "global_code": "862476FV+54"
#             },
#             "price_level": 3,
#             "rating": 4.5,
#             "reference": "ChIJbeqvYxO1RIYR5zZEcyfr02s",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 762,
#             "vicinity": "1200 W 6th St, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.29820429999999,
#                     "lng": -97.7050625
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.29962762989271,
#                         "lng": -97.70367182010729
#                     },
#                     "southwest": {
#                         "lat": 30.29692797010727,
#                         "lng": -97.70637147989274
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "B.D. Riley's Irish Pub at Mueller",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100013179382489867933\">Manda</a>"
#                     ],
#                     "photo_reference": "ATtYBwIqtb1T8PPaOHgryhQJmxO6AQfK83Ys4_gB4v0EStn6n-0NoErSl247VuRXi6xK94DTHbKd43Wo8C8G_BAt3LDiNtJn6uPNx9Pw9_RWOFnK3MHlq5ZL3AWPDxGIt62jh-SLLN1I2lgi88KVQIsF22uykOJ7imi6zjytAUc_AXCOwUL_",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJrS3m3_i1RIYR1W5mi2PlZYI",
#             "plus_code": {
#                 "compound_code": "77XV+7X Austin, Texas",
#                 "global_code": "862477XV+7X"
#             },
#             "price_level": 2,
#             "rating": 4.4,
#             "reference": "ChIJrS3m3_i1RIYR1W5mi2PlZYI",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1050,
#             "vicinity": "1905 Aldrich St #130, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.26867829999999,
#                     "lng": -97.74235069999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.27005847989272,
#                         "lng": -97.74110427010727
#                     },
#                     "southwest": {
#                         "lat": 30.26735882010728,
#                         "lng": -97.74380392989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "Upstairs at Caroline - OPEN",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103694869205930159701\">Justin Horlyk</a>"
#                     ],
#                     "photo_reference": "ATtYBwLfROl03gKGIDvwLCiq2S_DcjpTjv6SMus1m7WcGYKqvUZEIeBsjcfPvcH0WMB--RDRO-CWcTpV5k-T7iP0CLJVyuiVWTzmzaGuLSzPdKtx0HMoAE-vNMnZtJ8dXJ5aXAIHFY3oumEeEL2CcJbB2-C_sekITDx4DC9Y9Kcl26wZAGLa",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJQyfp5wm1RIYRuYHlan7PCQs",
#             "plus_code": {
#                 "compound_code": "7795+F3 Austin, Texas",
#                 "global_code": "86247795+F3"
#             },
#             "price_level": 2,
#             "rating": 4.4,
#             "reference": "ChIJQyfp5wm1RIYRuYHlan7PCQs",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 645,
#             "vicinity": "621 Congress Ave STE 201, Austin"
#         }
#     ],
#     "status": "OK"
# }

# %%
print(places_data["results"][0])
# Out:
# {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 30.249437, 'lng': -97.766893}, 'viewport': {'northeast': {'lat': 30.25090932989272, 'lng': -97.76570852010728}, 'southwest': {'lat': 30.24820967010728, 'lng': -97.76840817989272}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png', 'name': 'Corner Bar', 'opening_hours': {'open_now': False}, 'photos': [{'height': 3648, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100335561761196663504">Corner Bar</a>'], 'photo_reference': 'ATtYBwIzSVE6PCO8M1IXPeM87klkuDTAkQN042RKxCIX2VBYnuuhSLtQj-LGB9G-Sq9lya0oghpUq2PyNjMyxjuV3JlmOCG7a_y_tTn5bXJrUgyzoKIB7H7vexCnkKrWMUsbZaQ8wVZNTE56v_LInlLatahrmeTvCpu3Of-0VzcjQyjhyM8N', 'width': 5472}], 'place_id': 'ChIJc8VGEN-0RIYR_47qj-CsoQw', 'plus_code': {'compound_code': '66XM+Q6 Austin, Texas', 'global_code': '862466XM+Q6'}, 'price_level': 1, 'rating': 4.5, 'reference': 'ChIJc8VGEN-0RIYR_47qj-CsoQw', 'scope': 'GOOGLE', 'types': ['bar', 'point_of_interest', 'establishment'], 'user_ratings_total': 363, 'vicinity': '1901 S Lamar Blvd, Austin'}

# %%
bars = []

for result in places_data["results"]:
    #print(result["business_status"])
    bar_lat = result["geometry"]["location"]["lat"]
    bar_lng = result["geometry"]["location"]["lng"]
    bar_name = result["name"]
    bar_location = result["vicinity"]
    bars.append({"Bar Name": bar_name,
                "Lat": bar_lat,
                 "Lng": bar_lng,
                 "Location": bar_location})                 
    
bars_data = pd.DataFrame(bars)    
bars_data
# Out:
#                              Bar Name        Lat        Lng  \
# 0                          Corner Bar  30.249437 -97.766893
# 1               Revelry Kitchen + Bar  30.263768 -97.727788
# 2                       Workhorse Bar  30.317858 -97.722036
# 3                   Dive Bar & Lounge  30.279892 -97.742087
# 4                       Lavaca St Bar  30.241267 -97.785023
# 5                            Star Bar  30.269952 -97.748538
# 6                            Haymaker  30.284824 -97.717586
# 7                  The Roosevelt Room  30.267789 -97.746277
# 8                   Gibson Street Bar  30.255018 -97.761916
# 9             Corner Restaurant & Bar  30.264570 -97.743832
# 10                      Cain & Abel's  30.287778 -97.744444
# 11            The Garden Grille & Bar  30.222000 -97.688515
# 12                          HandleBar  30.266620 -97.742054
# 13               Champions Sports Bar  30.265519 -97.740274
# 14                            Key Bar  30.269722 -97.749390
# 15                        Nickel City  30.268651 -97.728072
# 16       Cedar Door Patio Bar & Grill  30.264093 -97.742583
# 17                 Clark's Oyster Bar  30.272994 -97.757171
# 18  B.D. Riley's Irish Pub at Mueller  30.298204 -97.705062
# 19        Upstairs at Caroline - OPEN  30.268678 -97.742351
#
#                             Location  \
# 0          1901 S Lamar Blvd, Austin
# 1              1410 E 6th St, Austin
# 2       100 N Loop Blvd E #B, Austin
# 3          1703 Guadalupe St, Austin
# 4          3121 S Lamar Blvd, Austin
# 5               600 W 6th St, Austin
# 6              2310 Manor Rd, Austin
# 7               307 W 5th St, Austin
# 8          1109 S Lamar Blvd, Austin
# 9               110 E 2nd St, Austin
# 10        2313 Rio Grande St, Austin
# 11       7610 John Glenn Way, Austin
# 12              121 E 5th St, Austin
# 13              300 E 4th St, Austin
# 14              617 W 6th St, Austin
# 15            1133 E 11th St, Austin
# 16      201 Brazos St bldg A, Austin
# 17             1200 W 6th St, Austin
# 18      1905 Aldrich St #130, Austin
# 19  621 Congress Ave STE 201, Austin
#
#                                                 Types
# 0             [bar, point_of_interest, establishment]
# 1   [bar, restaurant, food, point_of_interest, est...
# 2             [bar, point_of_interest, establishment]
# 3   [bar, restaurant, food, point_of_interest, est...
# 4   [bar, restaurant, food, point_of_interest, est...
# 5             [bar, point_of_interest, establishment]
# 6   [bar, restaurant, food, point_of_interest, est...
# 7   [bar, restaurant, food, point_of_interest, est...
# 8             [bar, point_of_interest, establishment]
# 9   [restaurant, bar, food, point_of_interest, est...
# 10  [bar, restaurant, food, point_of_interest, est...
# 11  [bar, restaurant, food, point_of_interest, est...
# 12  [bar, night_club, point_of_interest, establish...
# 13  [bar, restaurant, food, point_of_interest, est...
# 14  [bar, night_club, point_of_interest, establish...
# 15            [bar, point_of_interest, establishment]
# 16  [bar, restaurant, food, point_of_interest, est...
# 17  [bar, restaurant, food, point_of_interest, est...
# 18  [bar, restaurant, food, point_of_interest, est...
# 19  [bar, restaurant, food, point_of_interest, est...

# %%
austin_bars = bars_data

# %%
# Geo coordinates
target_coordinates = "30.266666, -97.733330"
target_search = "Liquor Stores"
target_radius = 8000
target_type = "retail"

# set up parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response = requests.get(base_url, params=params)

# %%
# print the response url
# print(response.url)

# %%
# convert response to json
stores_data = response.json()

# Print pretty
print(json.dumps(stores_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "ATtYBwK0tpegkY8avueRciCs1FnuXJTxdXWK8-NTxhr3Uy0j5bXboBYcqx1LpgjrY1ychPAEWSPDMJLT2c4wvtwYtsmdFSA3OFL4Nxi11ITUx1fHt702lAju2fWe2gXm6sMQndIWGocgi8zxkqwpDH6MgZ4Xxae2OYxcj4hr0N2PC95708-v6lxRcCQAeTHWbjf-Q9KXEdHrSEim7VjmPm2f8ZsGGbkJbuqVwkpaCuB1VOZDOTjXdhag0fBuRl2Oixx2kgGnkK_vdO8-9ugleKvQh0Kt6vj89AjqMavCxiBEtNGDeLAuyVoMIUO-5rfDh1hXCvl-0iucSon2Dx8lZUIWqsKp-qhGBjtKmdsS6MY6n1KUPs_P2_n8zFpFo9dY95Q_dq4W8h_2MBCCvsTflb1dgHLF7L047B1f5TeHBJzjuUEJZQ1GWJ3Qr4AeFhaL-HEY-yL6dj8SqNc",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.2471157,
#                     "lng": -97.77339620000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.24847372989272,
#                         "lng": -97.77191087010728
#                     },
#                     "southwest": {
#                         "lat": 30.24577407010728,
#                         "lng": -97.77461052989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Chris's Liquor Stores",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3264,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107698087138846960095\">Chris&#39;s Liquor Stores</a>"
#                     ],
#                     "photo_reference": "ATtYBwKCrfuvEwW07SuvL8ouQhWn1lLFwpleIy-zhT-EM93Kp_l_dZ8sP1y7drXQUBj7vzjKymBPiU2f9mtuwMpQArxBsgvhrsfmlbizCl8fhJmjy6z-FZ6dOaug17zYAJ9xO4JJWmJ-Rf6KfP0qHc8VH5fobIpwdaKPWMk1TSYbingxZ_rd",
#                     "width": 4928
#                 }
#             ],
#             "place_id": "ChIJs8wI8Na0RIYRsI9OVMfNcGQ",
#             "plus_code": {
#                 "compound_code": "66WG+RJ Austin, Texas",
#                 "global_code": "862466WG+RJ"
#             },
#             "rating": 4.5,
#             "reference": "ChIJs8wI8Na0RIYRsI9OVMfNcGQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "liquor_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 117,
#             "vicinity": "2203 S Lamar Blvd, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.2001336,
#                     "lng": -97.7863071
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.20140587989273,
#                         "lng": -97.78482397010728
#                     },
#                     "southwest": {
#                         "lat": 30.19870622010728,
#                         "lng": -97.78752362989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "ACE LIQUOR STORE",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1536,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116780138236799593193\">Bonny Uwakweh</a>"
#                     ],
#                     "photo_reference": "ATtYBwLFD6JzjDPa0i3iydm6VWFni2MuU_SVj_4HmiA5L9xbAPdATiXY809l1LSOGEAT0BU-dXnsbr7zw0zaM31quwEcOFrUmCZxaC3KB7UOS_ylx26dvUP__qUE2AbGpfda_w1FQ0I3NAHKqlN0NY2iKmRyEnGFnuyspx-cqaDZuVjoc4J8",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJywGSQKtMW4YR89TuBsVxPkw",
#             "plus_code": {
#                 "compound_code": "6627+3F Austin, Texas",
#                 "global_code": "86246627+3F"
#             },
#             "rating": 3.7,
#             "reference": "ChIJywGSQKtMW4YR89TuBsVxPkw",
#             "scope": "GOOGLE",
#             "types": [
#                 "liquor_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 35,
#             "vicinity": "6400 S 1st St #E, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.2413119,
#                     "lng": -97.7604654
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.24260837989272,
#                         "lng": -97.75899807010727
#                     },
#                     "southwest": {
#                         "lat": 30.23990872010727,
#                         "lng": -97.76169772989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Warehouse Liquors",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1536,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105789841767043696421\">Warehouse Liquors</a>"
#                     ],
#                     "photo_reference": "ATtYBwLWYeC3ZCKO0oBRf8hwTMe45aMqxajunBTPdhVnHsJ1yCktLDPiF55Mp4a6acZjrds_5N6wLJtDjuMfBykk2SfBepcRxHZHlFZLjqcJ7_jHgSKkLRUmR32Di8YwwfJxv9vPP0GvmxFznp7qkZmt_0N2iS93ozwTHeHGUlW9wXJGHWqD",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJ0dpNMua0RIYRm8pFWtGVC5w",
#             "plus_code": {
#                 "compound_code": "66RQ+GR Austin, Texas",
#                 "global_code": "862466RQ+GR"
#             },
#             "rating": 4.3,
#             "reference": "ChIJ0dpNMua0RIYRm8pFWtGVC5w",
#             "scope": "GOOGLE",
#             "types": [
#                 "liquor_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 91,
#             "vicinity": "2424 S 1st St, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.26653079999999,
#                     "lng": -97.74165119999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.26794702989272,
#                         "lng": -97.74041222010727
#                     },
#                     "southwest": {
#                         "lat": 30.26524737010728,
#                         "lng": -97.74311187989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "All American Liquors",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108453367194726995354\">All American Liquors</a>"
#                     ],
#                     "photo_reference": "ATtYBwI5FSQ_3_r5zYYDlDnBEIAmnkcMDgDZ5TrtCXWz4HDiy5gpbVVdoVAxt8Fg8GDcsMAwRHBbHJ2f82AqlAWdMcDF-vilv74EXlmtXFuHsKL3oLW5IJp1XzuLPfif7GEZeW_mIS6Snlht1qMHefy-vdsbAb2dIAzfRK0fWr12CmsW2ZT5",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJR9rtJwi1RIYRUCaIrJmZ1EA",
#             "plus_code": {
#                 "compound_code": "7785+J8 Austin, Texas",
#                 "global_code": "86247785+J8"
#             },
#             "rating": 4.5,
#             "reference": "ChIJR9rtJwi1RIYRUCaIrJmZ1EA",
#             "scope": "GOOGLE",
#             "types": [
#                 "liquor_store",
#                 "food",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 67,
#             "vicinity": "411 Brazos St #100, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.238142,
#                     "lng": -97.73935399999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.23952812989272,
#                         "lng": -97.73791012010729
#                     },
#                     "southwest": {
#                         "lat": 30.23682847010728,
#                         "lng": -97.74060977989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Travis Heights Wine & Spirits",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100854357406530749923\">Robert Hillman</a>"
#                     ],
#                     "photo_reference": "ATtYBwJTJDWBftKlFrSDJumS4N90xBz9CDk8at4Ew83MPEVYtDJVpIQX_wLtZcnC7rPrbggzq-J4nLYIJ4cn6Oyvd38zMb3tPz3MCgGrLrMBjw1wUzq5ZCCrzCr0XIs_eOGJJEE8ljXnz0Xfu2ehEdPpKwootu4mIa5Ii3SF1Rpz88_E_bsT",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJ84o_-1i0RIYRgyAbo4Flgc0",
#             "plus_code": {
#                 "compound_code": "67Q6+77 Austin, Texas",
#                 "global_code": "862467Q6+77"
#             },
#             "rating": 4.7,
#             "reference": "ChIJ84o_-1i0RIYRgyAbo4Flgc0",
#             "scope": "GOOGLE",
#             "types": [
#                 "liquor_store",
#                 "food",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 94,
#             "vicinity": "1948 S IH 35 Frontage Rd, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.2648683,
#                     "lng": -97.7442284
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.26618442989272,
#                         "lng": -97.74277387010727
#                     },
#                     "southwest": {
#                         "lat": 30.26348477010728,
#                         "lng": -97.74547352989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Urban Wine + Liquor",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1463,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100015636561581645330\">100015636561581645330</a>"
#                     ],
#                     "photo_reference": "ATtYBwIQ9DkPytyjaZxCk7Z-uhZCtw1Y5mThflSnveRpSJLm-oYg7G5YbZQW64OmSPFY8cPR0WKwD7W428ye6q4fWt8cIbQ4-SP4tVIw_U2LnqOsTveG_UDjjTu55tyBBFx9YXJ1VAoB6P6eJyL57Q2yP86KrvT-ImHo2ioXqG5WLOOL3m6j",
#                     "width": 2500
#                 }
#             ],
#             "place_id": "ChIJEfmCgwi1RIYRRaXH9uKcJH8",
#             "plus_code": {
#                 "compound_code": "7774+W8 Austin, Texas",
#                 "global_code": "86247774+W8"
#             },
#             "rating": 4.1,
#             "reference": "ChIJEfmCgwi1RIYRRaXH9uKcJH8",
#             "scope": "GOOGLE",
#             "types": [
#                 "liquor_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 67,
#             "vicinity": "200 Congress Ave, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.3211232,
#                     "lng": -97.70541519999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.32252542989272,
#                         "lng": -97.70415012010727
#                     },
#                     "southwest": {
#                         "lat": 30.31982577010728,
#                         "lng": -97.70684977989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Johnnie's Liquor Store",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3120,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101797191992221415109\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwKwbDi1kkMysXrkwPYv1bOPsxil7dOIjvfWOS1yg5TnzjekNkiU2_o0S-Cp-l-D2n_Kbe3ww7XMkHwfr6GNNDNwwlfb562WYv5tWzw3XagmAFrVQL9PizOwp467A7vP9_Il8I2amuC-Wpbtq_HMguK21Vle2dl2zC4RDYsIwcdb1x7t",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJJYAAg-HJRIYRhf02wh4ND2M",
#             "plus_code": {
#                 "compound_code": "87CV+CR Austin, Texas",
#                 "global_code": "862487CV+CR"
#             },
#             "rating": 4.5,
#             "reference": "ChIJJYAAg-HJRIYRhf02wh4ND2M",
#             "scope": "GOOGLE",
#             "types": [
#                 "liquor_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 23,
#             "vicinity": "6029 N Interstate Hwy 35, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.2745028,
#                     "lng": -97.7199498
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.27584522989272,
#                         "lng": -97.71864642010729
#                     },
#                     "southwest": {
#                         "lat": 30.27314557010727,
#                         "lng": -97.72134607989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "C & M Liquors",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112476506806842786612\">East Austin Realty Expert - Scott Cooper Smith</a>"
#                     ],
#                     "photo_reference": "ATtYBwJbIYGbN0K4j6XwGJK40kDYZO83uiaypZEAZPnYisg69KwQJJpEh5X68hQoqbuoSkKJVZFn_BGh-CRzpyoWS2kxY15qMiYCjbD-pjEaipjx9JOy1GS_gaCYGImqohCx5sRcpMN-xhIiTna64b2byKjcni7qZgaklEMlHW8r8gdjoGr6",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJc8V-gL-1RIYRMuhmDd-KFg8",
#             "plus_code": {
#                 "compound_code": "77FJ+R2 Austin, Texas",
#                 "global_code": "862477FJ+R2"
#             },
#             "rating": 4.3,
#             "reference": "ChIJc8V-gL-1RIYRMuhmDd-KFg8",
#             "scope": "GOOGLE",
#             "types": [
#                 "liquor_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 24,
#             "vicinity": "1215 Chicon St, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.2723024,
#                     "lng": -97.6985488
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.27377712989272,
#                         "lng": -97.69711667010728
#                     },
#                     "southwest": {
#                         "lat": 30.27107747010728,
#                         "lng": -97.69981632989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Millpond Liquor Store",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 593,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116236751053265700960\">SMS fishing</a>"
#                     ],
#                     "photo_reference": "ATtYBwL71iEiqV1iZQZldZTNcOHwrhlgpmAiBvEHkeYakko7M83pRIIuoUSLCaph_2xyXenpcq2CmcgmJ1_2-jtI48yKI1DFKgThjAMaug7QHNrYsJTI6MVgHtcoXq2ZGBjqwBqi2Lnnozizecch5-u7qblCWDPK5mjWoogqHE08xff6QbRX",
#                     "width": 1404
#                 }
#             ],
#             "place_id": "ChIJfUOjp9i1RIYRMm9KWDoB6qI",
#             "plus_code": {
#                 "compound_code": "78C2+WH Austin, Texas",
#                 "global_code": "862478C2+WH"
#             },
#             "rating": 3.4,
#             "reference": "ChIJfUOjp9i1RIYRMm9KWDoB6qI",
#             "scope": "GOOGLE",
#             "types": [
#                 "liquor_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 35,
#             "vicinity": "1144 Airport Blvd, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.292154,
#                     "lng": -97.74295
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.29351697989272,
#                         "lng": -97.74149812010727
#                     },
#                     "southwest": {
#                         "lat": 30.29081732010727,
#                         "lng": -97.74419777989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Nueces Liquor",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103220619221394676696\">Adam Sessa</a>"
#                     ],
#                     "photo_reference": "ATtYBwLhWXVDuAsxnaDyVaI3cLsc7X9HI5nFJpcyQRcVzsmmbshwD9aPmTrQjPbSPyYaPF0YPptk9KC9YoIxKbxmOYRJqPomwkfq96O5eCZgD3Pe8k5o3ywjzMvgACly5cf-rsEVHzdPZUVMyLhVlrJgcOarkhOgGKnGCkNIq5_DwWo-e9-x",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJTWmLuHi1RIYRAB67pI_sD7c",
#             "plus_code": {
#                 "compound_code": "77R4+VR Austin, Texas",
#                 "global_code": "862477R4+VR"
#             },
#             "rating": 4.1,
#             "reference": "ChIJTWmLuHi1RIYRAB67pI_sD7c",
#             "scope": "GOOGLE",
#             "types": [
#                 "liquor_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 14,
#             "vicinity": "2700 Nueces St #103, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.2082055,
#                     "lng": -97.8151977
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.20952722989272,
#                         "lng": -97.81377482010728
#                     },
#                     "southwest": {
#                         "lat": 30.20682757010728,
#                         "lng": -97.81647447989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Chris's Liquor",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2340,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105632690813390885542\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwLqGagjoNqEo6whSGSH3JMgy_qGVx00d58ABVn-eB3nqxhDGSX7FvlgOmUC8_AlxcFmJa7et7idPCGqctHz2xrH6UjmbIRSNl5gGgpF6cMiNylhQmXIfNUgS_TBHUVywPouftGsuFycCvuItVG5H19LGV9cezvIierk5Oe4fwNWIEt6",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJ1XjAeWRLW4YRvmQUNuPC208",
#             "plus_code": {
#                 "compound_code": "655M+7W Austin, Texas",
#                 "global_code": "8624655M+7W"
#             },
#             "rating": 4.3,
#             "reference": "ChIJ1XjAeWRLW4YRvmQUNuPC208",
#             "scope": "GOOGLE",
#             "types": [
#                 "liquor_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 69,
#             "vicinity": "6800 West Gate Blvd, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.3199716,
#                     "lng": -97.6946469
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.32136172989272,
#                         "lng": -97.69326287010728
#                     },
#                     "southwest": {
#                         "lat": 30.31866207010727,
#                         "lng": -97.69596252989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Chris Liquor",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109975671869016267873\">ELIE ELMURR</a>"
#                     ],
#                     "photo_reference": "ATtYBwIIWE9ofpacKMHrOOCIWtzVTvcBBkmBZPmr81axGnv7WB2bCAybg6Y0XdpecE2rGHtT9On0zfzwzwpU7f1kEqPx6d0CqY0DtpLEOkuISQ96_-3wnEwPZLpns4BJZ4_7VkWVRZQsi5DhrdbvffgQV4sgudNXCsnWEHx2EIJMjyLD-mlO",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJVxd5N_TJRIYR1pMajb1w1Eo",
#             "plus_code": {
#                 "compound_code": "8894+X4 Austin, Texas",
#                 "global_code": "86248894+X4"
#             },
#             "rating": 4.6,
#             "reference": "ChIJVxd5N_TJRIYR1pMajb1w1Eo",
#             "scope": "GOOGLE",
#             "types": [
#                 "liquor_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 50,
#             "vicinity": "6305 Cameron Rd #116, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.210435,
#                     "lng": -97.65263879999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.21164322989273,
#                         "lng": -97.65138862010727
#                     },
#                     "southwest": {
#                         "lat": 30.20894357010728,
#                         "lng": -97.65408827989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Mount Everest Liquor",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 952,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108326414594534286186\">Hill Liquor Store .</a>"
#                     ],
#                     "photo_reference": "ATtYBwKkQNS8Trqh7zUJ5Rx3rq0QTOlxK95D0oMKGHdoOGh0h0V8pe_djpkH2REdPRvtv-Oa6uIJ6bj4jAizGjSPe8JQmzclCNoGzfNRjFyYUhaLqbsyPkx5I7kwBxiM7wldsSji--X0ewkqF9teHICWNRuIhs8RFeT8p0qhbM-_7e_aDViN",
#                     "width": 1270
#                 }
#             ],
#             "place_id": "ChIJZWBuHNWwRIYRolQPqaOOgns",
#             "plus_code": {
#                 "compound_code": "686W+5W Del Valle, Texas",
#                 "global_code": "8624686W+5W"
#             },
#             "rating": 4.3,
#             "reference": "ChIJZWBuHNWwRIYRolQPqaOOgns",
#             "scope": "GOOGLE",
#             "types": [
#                 "liquor_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 21,
#             "vicinity": "2765 E Hwy 71, Del Valle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.3262799,
#                     "lng": -97.74066710000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.32761507989272,
#                         "lng": -97.73947947010728
#                     },
#                     "southwest": {
#                         "lat": 30.32491542010728,
#                         "lng": -97.74217912989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "King Liquor",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3036,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108775782943555243840\">Matt Guthrie</a>"
#                     ],
#                     "photo_reference": "ATtYBwKFtG7yWrDziEd4y1z_eaNxu93iqDyzfdj2lUvpFk2WXJEbk760RKNBQtR-cVKG9_CFmHc8E2FVTAcjwPw2f1zaAyW7F7jIR_V2MfMjQUZi26GYaWYIfg9KIHtxfiN7RYvye60a_Dv1GkqT_WMrxZ-huIGNcFM6mR7FwH_Uocl6qMRq",
#                     "width": 4048
#                 }
#             ],
#             "place_id": "ChIJyz8kN1_KRIYRosUIkqT6OJU",
#             "plus_code": {
#                 "compound_code": "87G5+GP Austin, Texas",
#                 "global_code": "862487G5+GP"
#             },
#             "rating": 4.4,
#             "reference": "ChIJyz8kN1_KRIYRosUIkqT6OJU",
#             "scope": "GOOGLE",
#             "types": [
#                 "liquor_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 91,
#             "vicinity": "5310 Burnet Rd, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.2764234,
#                     "lng": -97.75190099999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.27770612989271,
#                         "lng": -97.75043617010728
#                     },
#                     "southwest": {
#                         "lat": 30.27500647010727,
#                         "lng": -97.75313582989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Wiggy's Wine & Spirits",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1655,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103220619221394676696\">Adam Sessa</a>"
#                     ],
#                     "photo_reference": "ATtYBwIiu7xeEyOVRLACpZz67F-SfA7p8ivsOwgC4pPr2R1f1MVd5imiuq1HWD5lRhZiH0WCSSUrsFoy5-wWmtcyjAuKn2zOYKhdVFnjsGJUuY7L5HsROQ9qmFIqO0Apxr0UH-eRRBawIYfuLI2FeRPqvEi18Xju3ds_5TgbCimVnr-q9XP4",
#                     "width": 3300
#                 }
#             ],
#             "place_id": "ChIJqdbrpHK1RIYRWsESrR3Wbb4",
#             "plus_code": {
#                 "compound_code": "76GX+H6 Austin, Texas",
#                 "global_code": "862476GX+H6"
#             },
#             "rating": 4.4,
#             "reference": "ChIJqdbrpHK1RIYRWsESrR3Wbb4",
#             "scope": "GOOGLE",
#             "types": [
#                 "liquor_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 32,
#             "vicinity": "1104 N Lamar Blvd, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.2571544,
#                     "lng": -97.7465024
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.25851512989272,
#                         "lng": -97.74520077010727
#                     },
#                     "southwest": {
#                         "lat": 30.25581547010728,
#                         "lng": -97.74790042989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "New World Liquor",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2880,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111552525292142507202\">Anna Richardson Griffin</a>"
#                     ],
#                     "photo_reference": "ATtYBwLVxqJbeitnd4spMP25Bge_linZ6UFTbJJ-MRj6g9ZQr0jQCOVTMraT9-lTGxRVp8u8w0WQQH_tvNNIMlKmH8LlCnQ2rIVr4BEbjWFf-tk3YHutOLiTSraQkpsO2xq4ocu9okEjsFEuAGqGEzmmKS6hslVYBgPOHaK-aaBNO9a73M0P",
#                     "width": 2160
#                 }
#             ],
#             "place_id": "ChIJleXfXAG1RIYRNSyqcNWS3kE",
#             "plus_code": {
#                 "compound_code": "7743+V9 Austin, Texas",
#                 "global_code": "86247743+V9"
#             },
#             "rating": 3,
#             "reference": "ChIJleXfXAG1RIYRNSyqcNWS3kE",
#             "scope": "GOOGLE",
#             "types": [
#                 "liquor_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 35,
#             "vicinity": "343 S Congress Ave, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.3058,
#                     "lng": -97.7153472
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.30721827989272,
#                         "lng": -97.71399037010727
#                     },
#                     "southwest": {
#                         "lat": 30.30451862010728,
#                         "lng": -97.71669002989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Home Town Liquor & Spirits",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106092671036879169656\">Clint Tuttle</a>"
#                     ],
#                     "photo_reference": "ATtYBwK7LKqGyzp_0SXfizWeiOWrL4W0oGWoWAoqjPlAwDqMlhQGUpXOj_MEIvZD-UWtAIP64c_b1Bu_AXRIPVmLd7OZW6A1uly_xzSauYCxbrNcR56RQBiqnT2B8eO1GKdPe2HZoeAP4cbxRdqfEi_t7WuQGJwnCd6ypzwPDqGS-uJkoobx",
#                     "width": 2448
#                 }
#             ],
#             "place_id": "ChIJQSNP-AvKRIYRWqRUUawiV0s",
#             "plus_code": {
#                 "compound_code": "874M+8V Austin, Texas",
#                 "global_code": "8624874M+8V"
#             },
#             "rating": 4.4,
#             "reference": "ChIJQSNP-AvKRIYRWqRUUawiV0s",
#             "scope": "GOOGLE",
#             "types": [
#                 "liquor_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 26,
#             "vicinity": "4631 Airport Blvd #112, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.2165629,
#                     "lng": -97.7397215
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.21777337989272,
#                         "lng": -97.73838997010729
#                     },
#                     "southwest": {
#                         "lat": 30.21507372010728,
#                         "lng": -97.74108962989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "A & B Liquors Inc",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105190583711144221590\">Marco Cardenas</a>"
#                     ],
#                     "photo_reference": "ATtYBwLu34hhf9itxfPRnMsPYTjbXNyPymQbQ7ShqeAyXvTlvpNld4162J8vDvIGfqc9UTN430zzd6SR2ff-YlAvsb_k3E70lJfY_8P6W_hXQmS7OkUpziZor6RnZoRGZRvLQQICuTRIPIyp9AoCOp7iBksAVOQdXOF-Laak45vs7WzyL6st",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJxyQ8Dn20RIYRPegX9BBt7Ds",
#             "plus_code": {
#                 "compound_code": "6786+J4 Austin, Texas",
#                 "global_code": "86246786+J4"
#             },
#             "rating": 4.3,
#             "reference": "ChIJxyQ8Dn20RIYRPegX9BBt7Ds",
#             "scope": "GOOGLE",
#             "types": [
#                 "liquor_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 161,
#             "vicinity": "2234 E Ben White Blvd, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.257175,
#                     "lng": -97.72596399999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.25871422989273,
#                         "lng": -97.72460272010728
#                     },
#                     "southwest": {
#                         "lat": 30.25601457010729,
#                         "lng": -97.72730237989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Zeke's Liquor",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108101753596400923320\">Michael Kellner</a>"
#                     ],
#                     "photo_reference": "ATtYBwI8hUe4sajJ4kEGYOpqPBwOyF8CddLNWSVklw4xclo3pClhSTDpdeuyN1-KBz-JLvzgbalHypMp6bEFJNA6oqF661_9KJzB29ZMrRoWWcJFXeBkfzZjt9L1kPobhqdkGanIK2BwmM_gFHBmr9yOFJ_5m2g5J6b3xy-xnOtMMMd3DWGS",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJaT7VhLO1RIYR2dWnP95TvgU",
#             "plus_code": {
#                 "compound_code": "774F+VJ Austin, Texas",
#                 "global_code": "8624774F+VJ"
#             },
#             "rating": 4.5,
#             "reference": "ChIJaT7VhLO1RIYR2dWnP95TvgU",
#             "scope": "GOOGLE",
#             "types": [
#                 "liquor_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 47,
#             "vicinity": "1711 E Cesar Chavez St ste d, Austin"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.2355076,
#                     "lng": -97.791124
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.23701432989272,
#                         "lng": -97.78969262010729
#                     },
#                     "southwest": {
#                         "lat": 30.23431467010728,
#                         "lng": -97.79239227989274
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Twin Liquors",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4128,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111013708775629725832\">Alex Bevan</a>"
#                     ],
#                     "photo_reference": "ATtYBwIPcnNEc2WFPOa61qc8g8P7fA-72vPn8xF2WFe4Tx23_NQ762YmgAXSSETxbgWHkW6y_DbqHZ1rU0nfg1AN9sLUXaZjUKQdcSD5hE7c-EdENln8OMTbiJ8GRlO3XMomFNnab0W_1fXqR_-h3R0CgXVdwpVctcUYajo4PqssVkBv9OV3",
#                     "width": 2322
#                 }
#             ],
#             "place_id": "ChIJexax_TBLW4YRe752TSVFECI",
#             "plus_code": {
#                 "compound_code": "66P5+6H Austin, Texas",
#                 "global_code": "862466P5+6H"
#             },
#             "rating": 4.1,
#             "reference": "ChIJexax_TBLW4YRe752TSVFECI",
#             "scope": "GOOGLE",
#             "types": [
#                 "liquor_store",
#                 "food",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 106,
#             "vicinity": "4001 S Lamar Blvd a, Austin"
#         }
#     ],
#     "status": "OK"
# }

# %%
print(stores_data["results"][0])
# Out:
# {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 30.2471157, 'lng': -97.77339620000001}, 'viewport': {'northeast': {'lat': 30.24847372989272, 'lng': -97.77191087010728}, 'southwest': {'lat': 30.24577407010728, 'lng': -97.77461052989273}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png', 'name': "Chris's Liquor Stores", 'opening_hours': {'open_now': True}, 'photos': [{'height': 3264, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107698087138846960095">Chris&#39;s Liquor Stores</a>'], 'photo_reference': 'ATtYBwKCrfuvEwW07SuvL8ouQhWn1lLFwpleIy-zhT-EM93Kp_l_dZ8sP1y7drXQUBj7vzjKymBPiU2f9mtuwMpQArxBsgvhrsfmlbizCl8fhJmjy6z-FZ6dOaug17zYAJ9xO4JJWmJ-Rf6KfP0qHc8VH5fobIpwdaKPWMk1TSYbingxZ_rd', 'width': 4928}], 'place_id': 'ChIJs8wI8Na0RIYRsI9OVMfNcGQ', 'plus_code': {'compound_code': '66WG+RJ Austin, Texas', 'global_code': '862466WG+RJ'}, 'rating': 4.5, 'reference': 'ChIJs8wI8Na0RIYRsI9OVMfNcGQ', 'scope': 'GOOGLE', 'types': ['liquor_store', 'point_of_interest', 'store', 'establishment'], 'user_ratings_total': 117, 'vicinity': '2203 S Lamar Blvd, Austin'}

# %%
liquor_stores = []

for result in stores_data["results"]:
    #print(result["business_status"])
    ls_lat = result["geometry"]["location"]["lat"]
    ls_lng = result["geometry"]["location"]["lng"]
    ls_name = result["name"]
    ls_location = result["vicinity"]
    liquor_stores.append({"Store Name": ls_name,
                "Lat": ls_lat,
                 "Lng": ls_lng,
                 "Store Location": ls_location})
    
liquor_stores_data = pd.DataFrame(liquor_stores)
liquor_stores_data
# Out:
#                        Store Name        Lat        Lng  \
# 0           Chris's Liquor Stores  30.247116 -97.773396
# 1                ACE LIQUOR STORE  30.200134 -97.786307
# 2               Warehouse Liquors  30.241312 -97.760465
# 3            All American Liquors  30.266531 -97.741651
# 4   Travis Heights Wine & Spirits  30.238142 -97.739354
# 5             Urban Wine + Liquor  30.264868 -97.744228
# 6          Johnnie's Liquor Store  30.321123 -97.705415
# 7                   C & M Liquors  30.274503 -97.719950
# 8           Millpond Liquor Store  30.272302 -97.698549
# 9                   Nueces Liquor  30.292154 -97.742950
# 10                 Chris's Liquor  30.208205 -97.815198
# 11                   Chris Liquor  30.319972 -97.694647
# 12           Mount Everest Liquor  30.210435 -97.652639
# 13                    King Liquor  30.326280 -97.740667
# 14         Wiggy's Wine & Spirits  30.276423 -97.751901
# 15               New World Liquor  30.257154 -97.746502
# 16     Home Town Liquor & Spirits  30.305800 -97.715347
# 17              A & B Liquors Inc  30.216563 -97.739722
# 18                  Zeke's Liquor  30.257175 -97.725964
# 19                   Twin Liquors  30.235508 -97.791124
#
#                           Store Location  \
# 0              2203 S Lamar Blvd, Austin
# 1               6400 S 1st St #E, Austin
# 2                  2424 S 1st St, Austin
# 3             411 Brazos St #100, Austin
# 4       1948 S IH 35 Frontage Rd, Austin
# 5               200 Congress Ave, Austin
# 6       6029 N Interstate Hwy 35, Austin
# 7                 1215 Chicon St, Austin
# 8              1144 Airport Blvd, Austin
# 9            2700 Nueces St #103, Austin
# 10           6800 West Gate Blvd, Austin
# 11          6305 Cameron Rd #116, Austin
# 12              2765 E Hwy 71, Del Valle
# 13                5310 Burnet Rd, Austin
# 14             1104 N Lamar Blvd, Austin
# 15            343 S Congress Ave, Austin
# 16        4631 Airport Blvd #112, Austin
# 17         2234 E Ben White Blvd, Austin
# 18  1711 E Cesar Chavez St ste d, Austin
# 19           4001 S Lamar Blvd a, Austin
#
#                                                 Types
# 0   [liquor_store, point_of_interest, store, estab...
# 1   [liquor_store, point_of_interest, store, estab...
# 2   [liquor_store, point_of_interest, store, estab...
# 3   [liquor_store, food, point_of_interest, store,...
# 4   [liquor_store, food, point_of_interest, store,...
# 5   [liquor_store, point_of_interest, store, estab...
# 6   [liquor_store, point_of_interest, store, estab...
# 7   [liquor_store, point_of_interest, store, estab...
# 8   [liquor_store, point_of_interest, store, estab...
# 9   [liquor_store, point_of_interest, store, estab...
# 10  [liquor_store, point_of_interest, store, estab...
# 11  [liquor_store, point_of_interest, store, estab...
# 12  [liquor_store, point_of_interest, store, estab...
# 13  [liquor_store, point_of_interest, store, estab...
# 14  [liquor_store, point_of_interest, store, estab...
# 15  [liquor_store, point_of_interest, store, estab...
# 16  [liquor_store, point_of_interest, store, estab...
# 17  [liquor_store, point_of_interest, store, estab...
# 18  [liquor_store, point_of_interest, store, estab...
# 19  [liquor_store, food, point_of_interest, store,...

# %%
austin_bars = pd.merge(bars_data, liquor_stores_data, on="Types", how="outer")

austin_bars
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-3c4a5208c789> in <module>
# ----> 1 austin_bars = pd.merge(bars_data, liquor_stores_data, on="Types", how="outer")
#       2
#       3 austin_bars
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      86         validate=validate,
#      87     )
# ---> 88     return op.get_result()
#      89
#      90
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     641             self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     642
# --> 643         join_index, left_indexer, right_indexer = self._get_join_info()
#     644
#     645         ldata, rdata = self.left._data, self.right._data
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_join_info(self)
#     860             )
#     861         else:
# --> 862             (left_indexer, right_indexer) = self._get_join_indexers()
#     863
#     864             if self.right_index:
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_join_indexers(self)
#     838     def _get_join_indexers(self):
#     839         """ return the join indexers """
# --> 840         return _get_join_indexers(
#     841             self.left_join_keys, self.right_join_keys, sort=self.sort, how=self.how
#     842         )
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_join_indexers(left_keys, right_keys, sort, how, **kwargs)
#    1309         for n in range(len(left_keys))
#    1310     )
# -> 1311     zipped = zip(*mapped)
#    1312     llab, rlab, shape = [list(x) for x in zipped]
#    1313
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in <genexpr>(.0)
#    1306     # get left & right join labels and num. of levels at each location
#    1307     mapped = (
# -> 1308         _factorize_keys(left_keys[n], right_keys[n], sort=sort)
#    1309         for n in range(len(left_keys))
#    1310     )
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _factorize_keys(lk, rk, sort)
#    1915     rizer = klass(max(len(lk), len(rk)))
#    1916
# -> 1917     llab = rizer.factorize(lk)
#    1918     rlab = rizer.factorize(rk)
#    1919
#
# pandas\_libs\hashtable.pyx in pandas._libs.hashtable.Factorizer.factorize()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_labels()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'
