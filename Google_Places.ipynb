# %%
#Dependencies
import requests
import json
import pandas as pd

#Google developer API Key
from config import gkey

# %%
# Geo coordinates
target_coordinates = "30.266666, -97.733330"
target_search = "Bars"
target_radius = 8000
target_type = "bars"

# set up parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response = requests.get(base_url, params=params)

# %%
# print the response url
# print(response.url)

# %%
# convert response to json
places_data = response.json()

# Print pretty
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "ATtYBwIzTqRD3GOMBTPwH1KrjX9mQAbqSYfMdq2dJ4adtegRwvGMAb-LVQNpNKolVph1KAUnMDz66s-7J0S460BjbGOFXlYFBLBY56S2rCOERrIGsX0Cvy3VXMeQaX6PExHuTV5iJdM8x0n_EKMPBx1si95a8Xk0AdU4fRHNzu1GEDWEDXL33I16nQ9rqgHLtZajCYiDkzyFdANHwRgSTS1r3sQTUbIBn8tSW7_YmTrGAqjSzb87lftsTxkbHnfjAhmM4HIYPZXRGqaQkyct2DHuzThIYDKZD4b9btOgOs4xzdUdkoI0R00lmRDEyUOQ-FsBPeXvousBKHgBbT4SdORR-e4dKRgR21Z-FmhIktjEqRgvAWHYW8oeW2-D288bKphZKERnzlEOdkxmVMIUclGPe91N7UG83PZWauyi0O_rnjiI3N7OG-B5RlsI5Cvo",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.249437,
#                     "lng": -97.766893
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.25090932989272,
#                         "lng": -97.76570852010728
#                     },
#                     "southwest": {
# ...

# %%
print(places_data["results"][0])
# Out:
# {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 30.249437, 'lng': -97.766893}, 'viewport': {'northeast': {'lat': 30.25090932989272, 'lng': -97.76570852010728}, 'southwest': {'lat': 30.24820967010728, 'lng': -97.76840817989272}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png', 'name': 'Corner Bar', 'opening_hours': {'open_now': False}, 'photos': [{'height': 3648, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100335561761196663504">Corner Bar</a>'], 'photo_reference': 'ATtYBwIzSVE6PCO8M1IXPeM87klkuDTAkQN042RKxCIX2VBYnuuhSLtQj-LGB9G-Sq9lya0oghpUq2PyNjMyxjuV3JlmOCG7a_y_tTn5bXJrUgyzoKIB7H7vexCnkKrWMUsbZaQ8wVZNTE56v_LInlLatahrmeTvCpu3Of-0VzcjQyjhyM8N', 'width': 5472}], 'place_id': 'ChIJc8VGEN-0RIYR_47qj-CsoQw', 'plus_code': {'compound_code': '66XM+Q6 Austin, Texas', 'global_code': '862466XM+Q6'}, 'price_level': 1, 'rating': 4.5, 'reference': 'ChIJc8VGEN-0RIYR_47qj-CsoQw', 'scope': 'GOOGLE', 'types': ['bar', 'poin
# ...

# %%
bars = []

for result in places_data["results"]:
    #print(result["business_status"])
    bar_lat = result["geometry"]["location"]["lat"]
    bar_lng = result["geometry"]["location"]["lng"]
    bar_name = result["name"]
    bars.append({"Lat": bar_lat,
                 "Lng": bar_lng,
                 "Bar Name": bar_name})
    
bars_data = pd.DataFrame(bars)    
bars_data
# Out:
#           Lat        Lng                           Bar Name
# 0   30.249437 -97.766893                         Corner Bar
# 1   30.263768 -97.727788              Revelry Kitchen + Bar
# 2   30.317858 -97.722036                      Workhorse Bar
# 3   30.279892 -97.742087                  Dive Bar & Lounge
# 4   30.241267 -97.785023                      Lavaca St Bar
# 5   30.269952 -97.748538                           Star Bar
# 6   30.284824 -97.717586                           Haymaker
# 7   30.267789 -97.746277                 The Roosevelt Room
# 8   30.255018 -97.761916                  Gibson Street Bar
# 9   30.264570 -97.743832            Corner Restaurant & Bar
# 10  30.287778 -97.744444                      Cain & Abel's
# 11  30.222000 -97.688515            The Garden Grille & Bar
# 12  30.266620 -97.742054                          HandleBar
# 13  30.265519 -97.740274               Champions Sports Bar
# 14  30.269722 -97.749390                            Key Bar
# ...
