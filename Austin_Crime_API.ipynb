# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import gmaps
import os
import apikey as api_key
import json
import ipywidgets
from sodapy import Socrata

# %%
client = Socrata("data.austintexas.gov", None)
results = client.get("fdj4-gpfu", limit=10000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
results_df.head()
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#   incident_report_number                     crime_type ucr_code  \
# 0            20205052927          BURGLARY OF RESIDENCE      500
# 1            20205052922              CRIMINAL MISCHIEF     1400
# 2            20205052926          BURGLARY OF RESIDENCE      500
# 3            20203610751  VIOL CITY ORDINANCE -FIREWORK     3201
# 4            20205052899           THEFT BY SHOPLIFTING      607
#
#   family_violence            occ_date_time                 occ_date occ_time  \
# 0               N  2020-12-26T21:00:00.000  2020-12-26T00:00:00.000     2100
# 1               N  2020-12-26T19:15:00.000  2020-12-26T00:00:00.000     1915
# 2               N  2020-12-26T18:15:00.000  2020-12-26T00:00:00.000     1815
# 3               N  2020-12-26T15:49:00.000  2020-12-26T00:00:00.000     1549
# 4               N  2020-12-26T15:00:00.000  2020-12-26T00:00:00.000     1500
#
# ...

# %%
crime_type= results_df['crime_type']
print(crime_type)
# Out:
# 0                BURGLARY OF RESIDENCE
# 1                    CRIMINAL MISCHIEF
# 2                BURGLARY OF RESIDENCE
# 3        VIOL CITY ORDINANCE -FIREWORK
# 4                 THEFT BY SHOPLIFTING
#                      ...
# 9995                DATING DISTURBANCE
# 9996                ROBBERY BY ASSAULT
# 9997     BURGLARY OF VEH-NO SUSPECT/FU
# 9998    INJ TO ELDERLY   FAM/DATE VIOL
# 9999     AGG ASSAULT FAM/DATE VIOLENCE
# Name: crime_type, Length: 10000, dtype: object

# %%
# Import CSV instead
crime_path = "Crime_Reports.csv"
crime_data = pd.read_csv(crime_path)
crime_data.head()
# Out:
#    Incident Number Highest Offense Description  Highest Offense Code  \
# 0     2.019157e+10               FRAUD - OTHER                  1199
# 1     2.019155e+10              DEADLY CONDUCT                   408
# 2     2.019502e+10      THEFT OF LICENSE PLATE                   614
# 3     2.020501e+10               RUNAWAY CHILD                  4100
# 4     2.019167e+10       BURGLARY OF RESIDENCE                   500
#
#   Family Violence Occurred Date Time Occurred Date  Occurred Time  \
# 0               N     6/3/2019 16:00      6/3/2019         1600.0
# 1               N      6/4/2019 3:12      6/4/2019          312.0
# 2               N     6/3/2019 15:00      6/3/2019         1500.0
# 3               N    2/22/2020 18:00     2/22/2020         1800.0
# 4               N    6/14/2019 12:00     6/14/2019         1200.0
#
#   Report Date Time Report Date  Report Time  ... Census Tract  \
# 0   6/6/2019 17:34    6/6/2019       1734.0  ...       203.11
# ...

# %%
crime_types= crime_data['Highest Offense Description']
print(crime_types)
# Out:
# 0                       FRAUD - OTHER
# 1                      DEADLY CONDUCT
# 2              THEFT OF LICENSE PLATE
# 3                       RUNAWAY CHILD
# 4               BURGLARY OF RESIDENCE
#                       ...
# 1048570                         THEFT
# 1048571    POSS OF DRUG PARAPHERNALIA
# 1048572    POSS OF DRUG PARAPHERNALIA
# 1048573    VOCO SOLICITATION PROHIBIT
# 1048574                    AUTO THEFT
# Name: Highest Offense Description, Length: 1048575, dtype: object

# %%
# Filter by Crime Type
# DWI, DWI 2ND, LIQUOR LAW VIOLATION/OTHER, 
# DUI - AGE 17 TO 20, DRIVING WHILE INTOX / FELONY, PUBLIC INTOXICATION, POSSESSION OF MARIJUANA

offense_df = crime_data.set_index("Highest Offense Description", drop= False)
offenses_df = (offense_df.loc[offense_df["Highest Offense Description"].isin(["DWI","DWI 2ND","PUBLIC INTOXICATION", 
                                                                           "LIQUOR LAW VIOLATION/OTHER", "DRIVING WHILE INTOX / FELONY",
                                                                          "POSSESSION OF MARIJUANA", "DUI - AGE 17 TO 20"])])
offenses_df.head()
# Out:
#                              Incident Number Highest Offense Description  \
# Highest Offense Description
# DWI 2ND                         2.016152e+09                     DWI 2ND
# DWI                             2.019282e+10                         DWI
# LIQUOR LAW VIOLATION/OTHER      2.005409e+08  LIQUOR LAW VIOLATION/OTHER
# POSSESSION OF MARIJUANA         2.019151e+10     POSSESSION OF MARIJUANA
# POSSESSION OF MARIJUANA         2.019156e+10     POSSESSION OF MARIJUANA
#
#                              Highest Offense Code Family Violence  \
# Highest Offense Description
# DWI 2ND                                      2102               N
# DWI                                          2100               N
# LIQUOR LAW VIOLATION/OTHER                   2208               N
# POSSESSION OF MARIJUANA                      1803               N
# POSSESSION OF MARIJUANA                      1803               N
#
# ...

# %%
# Drop columns
new_offenses= offenses_df.drop(columns={"Incident Number", "Highest Offense Description",
                                     "Highest Offense Code", "Family Violence", 
                                     "Occurred Date Time", "Report Date Time",
                                     "Report Date", "Report Time", "Census Tract", 
                                     "Clearance Status", "Clearance Date", "Occurred Time",
                                     "UCR Category", "Category Description", 
                                     "Location", "Address", "Location Type", "Council District", 
                                     "APD Sector", "APD District", "PRA"})
new_offenses
# Out:
#                             Occurred Date  Zip Code  X-coordinate  \
# Highest Offense Description
# DWI 2ND                         1/15/2016   78745.0     3099641.0
# DWI                             10/9/2019   78701.0     3115403.0
# LIQUOR LAW VIOLATION/OTHER       1/4/2005   78704.0     3111587.0
# POSSESSION OF MARIJUANA         5/31/2019   78721.0     3130612.0
# POSSESSION OF MARIJUANA          6/5/2019   78744.0     3108421.0
# ...                                   ...       ...           ...
# PUBLIC INTOXICATION             1/14/2003   78701.0     3114632.0
# DWI 2ND                        12/31/2003   78701.0     3114907.0
# DWI                             2/11/2013   78741.0     3127106.0
# PUBLIC INTOXICATION             5/27/2004   78705.0     3113584.0
# DWI                             7/22/2009   78745.0     3098623.0
#
#                              Y-coordinate   Latitude  Longitude
# Highest Offense Description
# ...

# %%
g_key = "AIzaSyCQRY-TmfYIztg9E8oNyUjEknsy9e7KHNs"
gmaps.configure(api_key= g_key)

# %%
# mapping by zip, export to png
# running API for gun, liquor stores
# mapping heat map, export to png
